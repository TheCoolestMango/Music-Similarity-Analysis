# %% [markdown]
# ## Connect to Google Drive to download JSON file with preprocessed data

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load data from preprocessed JSON

# %%
import json

def load_data(json_path):
  with open(json_path, "r") as fp:
        data = json.load(fp)

  X = (data['mfcc']) # Contains name of the song and corresponding MFCC's
  y = (data['labels']) # Contains genre labels of each song
  return X, y

json_path = '/content/drive/MyDrive/DL/Project/Data/preprocess/mel_specs.json'
orig_x_data, orig_y_data = load_data(json_path)

# %% [markdown]
# ## Refactor data into numpy array of spectrograms

# %%
import numpy as np
import sys

x_data, y_data = [], []
for i in range(len(orig_x_data)):
  x_d = orig_x_data[i]
  for j in range(len(x_d)):
    x_data.append([x_d[j][0][0], np.array(x_d[j][1]).T])
    y_data.append(orig_y_data[i])
X = x_data
y = np.array(y_data)

# %% [markdown]
# ## Split data into train and test sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ## Divide data into pairs

# %%
def create_pairs(plots, labels):
  pair_plots, pair_labels, pair_names = [], [], []
  num_labels = len(np.unique(labels)) # number of labels
  
  # Get indices of songs of each genre
  indices = [np.where(labels == i)[0] for i in range(num_labels)]
  
  for idx1 in range(len(plots)):
    # Get the current song name, MFCC and genre
    name1 = plots[idx1][0]
    plot1 = plots[idx1][1]
    label1 = labels[idx1]

    # Take random MFCC of other song with the same genre
    idx2 = np.random.choice(indices[label1])
    name2 = plots[idx2][0]
    plot2 = plots[idx2][1]

    # Add pair
    pair_plots.append([plot1, plot2])
    pair_labels.append([1])
    pair_names.append([name1, name2])

    # Take random MFCC of other song with different genre
    idx3 = np.where(labels != label1)[0]
    rand_idx3 = np.random.choice(idx3)
    name3 = plots[rand_idx3][0]
    plot3 = plots[rand_idx3][1]

    # Add pair
    pair_plots.append([plot1, plot3])
    pair_labels.append([0])
    pair_names.append([name1, name3])
  return np.array(pair_plots), np.array(pair_labels), pair_names

tr_pairs, tr_y, tr_names = create_pairs(X_train, y_train)
ts_pairs, ts_y, ts_names = create_pairs(X_test, y_test)

# %% [markdown]
# ## Initialize network

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, Lambda, Conv2D, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import RMSprop, SGD, Adam
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K

def initialize_base_network(input_shape, embeddingDim=48):
    input = Input(shape=input_shape, name="base_input")
    x = Flatten(name="flatten_input")(input)
    x = Dense(256, activation='sigmoid', name="first_base_dense")(x)
    x = Dropout(0.1, name="first_dropout")(x)
    x = Dense(256, activation='sigmoid', name="second_base_dense")(x)
    x = Dropout(0.1, name="second_dropout")(x)
    x = Dense(256, activation='sigmoid', name="third_base_dense")(x)

    model = Model(inputs=input, outputs=x)
    print(model.summary())
    return model

def euclidean_distance(vects):
    x, y = vects
    sum_square = K.sum(K.square(x - y), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sum_square, K.epsilon()))


def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
shape = (13,130,1)
base_network = initialize_base_network(input_shape=shape)
# Create the left input and point to the base network
input_a = Input(shape=shape, name="left_input")
vect_output_a = base_network(input_a)

# Create the right input and point to the base network
input_b = Input(shape=shape, name="right_input")
vect_output_b = base_network(input_b)

# Measure the similarity of the two vector outputs
output = Lambda(euclidean_distance, name="output_layer", output_shape=eucl_dist_output_shape)([vect_output_a, vect_output_b])

# Specify the inputs and output of the model
model = Model([input_a, input_b], output)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  base_input (InputLayer)     [(None, 13, 130, 1)]      0
#
#  flatten_input (Flatten)     (None, 1690)              0
#
#  first_base_dense (Dense)    (None, 256)               432896
#
#  first_dropout (Dropout)     (None, 256)               0
#
#  second_base_dense (Dense)   (None, 256)               65792
#
#  second_dropout (Dropout)    (None, 256)               0
#
#  third_base_dense (Dense)    (None, 256)               65792
#
# =================================================================
# Total params: 564,480
# Trainable params: 564,480
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Single network representation

# %%
plot_model(base_network, show_shapes=True, show_layer_names=True, to_file='base-model.png')

# %% [markdown]
# ### Siamese netowrk representation

# %%
plot_model(model, show_shapes=True, show_layer_names=True, to_file='outer-model.png')

# %% [markdown]
# ## Train model

# %%
tr_y = tf.cast(tr_y, tf.float32)
ts_y = tf.cast(ts_y, tf.float32)
rms = RMSprop(learning_rate=0.0001)
model.compile(loss='mse', optimizer=rms, metrics=['accuracy'])
history = model.fit([tr_pairs[:,0], tr_pairs[:,1]], tr_y, epochs=500, batch_size=128, validation_data=([ts_pairs[:,0], ts_pairs[:,1]], ts_y))
# Out:
# Epoch 1/500
# 110/110 [==============================] - 2s 8ms/step - loss: 0.3256 - accuracy: 0.4999 - val_loss: 0.3923 - val_accuracy: 0.5002
# Epoch 2/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2547 - accuracy: 0.4896 - val_loss: 0.3970 - val_accuracy: 0.5002
# Epoch 3/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2526 - accuracy: 0.5024 - val_loss: 0.3954 - val_accuracy: 0.5002
# Epoch 4/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2525 - accuracy: 0.4963 - val_loss: 0.3952 - val_accuracy: 0.5002
# Epoch 5/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2527 - accuracy: 0.4964 - val_loss: 0.3917 - val_accuracy: 0.5002
# Epoch 6/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2524 - accuracy: 0.4961 - val_loss: 0.3916 - val_accuracy: 0.5002
# Epoch 7/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2526 - accuracy: 0.4938 - val_loss: 0.3841 - val_accuracy: 0.5002
# Epoch 8/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2528 - accuracy: 0.4913 - val_loss: 0.3880 - val_accuracy: 0.5002
# Epoch 9/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2519 - accuracy: 0.5024 - val_loss: 0.3888 - val_accuracy: 0.5002
# Epoch 10/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2526 - accuracy: 0.4925 - val_loss: 0.3935 - val_accuracy: 0.5002
# Epoch 11/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2525 - accuracy: 0.4938 - val_loss: 0.3925 - val_accuracy: 0.5002
# Epoch 12/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2522 - accuracy: 0.4994 - val_loss: 0.3914 - val_accuracy: 0.5002
# Epoch 13/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2520 - accuracy: 0.4979 - val_loss: 0.3907 - val_accuracy: 0.5002
# Epoch 14/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2533 - accuracy: 0.4859 - val_loss: 0.3808 - val_accuracy: 0.5002
# Epoch 15/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2521 - accuracy: 0.4952 - val_loss: 0.3851 - val_accuracy: 0.5002
# Epoch 16/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2524 - accuracy: 0.4957 - val_loss: 0.3858 - val_accuracy: 0.5002
# Epoch 17/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2524 - accuracy: 0.4955 - val_loss: 0.3815 - val_accuracy: 0.5002
# Epoch 18/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2521 - accuracy: 0.4961 - val_loss: 0.3887 - val_accuracy: 0.5002
# Epoch 19/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2518 - accuracy: 0.4991 - val_loss: 0.3852 - val_accuracy: 0.5002
# Epoch 20/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2520 - accuracy: 0.4956 - val_loss: 0.3839 - val_accuracy: 0.5002
# Epoch 21/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2518 - accuracy: 0.5006 - val_loss: 0.3814 - val_accuracy: 0.5002
# Epoch 22/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2521 - accuracy: 0.4951 - val_loss: 0.3852 - val_accuracy: 0.5002
# Epoch 23/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2517 - accuracy: 0.5031 - val_loss: 0.3874 - val_accuracy: 0.5002
# Epoch 24/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2514 - accuracy: 0.5022 - val_loss: 0.3831 - val_accuracy: 0.5002
# Epoch 25/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2523 - accuracy: 0.4918 - val_loss: 0.3877 - val_accuracy: 0.5002
# Epoch 26/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2508 - accuracy: 0.5083 - val_loss: 0.3874 - val_accuracy: 0.5002
# Epoch 27/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2517 - accuracy: 0.4976 - val_loss: 0.3848 - val_accuracy: 0.5002
# Epoch 28/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2521 - accuracy: 0.4984 - val_loss: 0.3770 - val_accuracy: 0.5002
# Epoch 29/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2517 - accuracy: 0.4978 - val_loss: 0.3815 - val_accuracy: 0.5002
# Epoch 30/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2519 - accuracy: 0.5054 - val_loss: 0.3861 - val_accuracy: 0.5002
# Epoch 31/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2513 - accuracy: 0.5003 - val_loss: 0.3837 - val_accuracy: 0.5002
# Epoch 32/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2519 - accuracy: 0.4959 - val_loss: 0.3798 - val_accuracy: 0.5002
# Epoch 33/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2517 - accuracy: 0.4989 - val_loss: 0.3732 - val_accuracy: 0.5002
# Epoch 34/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2516 - accuracy: 0.5019 - val_loss: 0.3819 - val_accuracy: 0.5002
# Epoch 35/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2516 - accuracy: 0.5060 - val_loss: 0.3799 - val_accuracy: 0.5002
# Epoch 36/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2508 - accuracy: 0.5077 - val_loss: 0.3778 - val_accuracy: 0.5000
# Epoch 37/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2510 - accuracy: 0.5050 - val_loss: 0.3838 - val_accuracy: 0.5002
# Epoch 38/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2519 - accuracy: 0.4969 - val_loss: 0.3820 - val_accuracy: 0.5002
# Epoch 39/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2517 - accuracy: 0.5000 - val_loss: 0.3866 - val_accuracy: 0.5002
# Epoch 40/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2518 - accuracy: 0.4970 - val_loss: 0.3898 - val_accuracy: 0.5002
# Epoch 41/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2517 - accuracy: 0.5032 - val_loss: 0.3881 - val_accuracy: 0.5000
# Epoch 42/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2512 - accuracy: 0.5031 - val_loss: 0.3858 - val_accuracy: 0.5002
# Epoch 43/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2517 - accuracy: 0.5055 - val_loss: 0.3823 - val_accuracy: 0.5002
# Epoch 44/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2514 - accuracy: 0.5013 - val_loss: 0.3923 - val_accuracy: 0.5002
# Epoch 45/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2514 - accuracy: 0.5059 - val_loss: 0.3901 - val_accuracy: 0.5002
# Epoch 46/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2513 - accuracy: 0.5012 - val_loss: 0.3869 - val_accuracy: 0.5002
# Epoch 47/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2516 - accuracy: 0.5023 - val_loss: 0.3929 - val_accuracy: 0.5002
# Epoch 48/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2518 - accuracy: 0.5014 - val_loss: 0.3916 - val_accuracy: 0.5002
# Epoch 49/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2516 - accuracy: 0.4994 - val_loss: 0.3859 - val_accuracy: 0.5002
# Epoch 50/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.
500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2505 - accuracy: 0.5126 - val_loss: 0.3776 - val_accuracy: 0.5002
# Epoch 80/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2506 - accuracy: 0.5097 - val_loss: 0.3699 - val_accuracy: 0.5002
# Epoch 81/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2506 - accuracy: 0.5069 - val_loss: 0.3686 - val_accuracy: 0.5002
# Epoch 82/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2502 - accuracy: 0.5082 - val_loss: 0.3717 - val_accuracy: 0.5002
# Epoch 83/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2504 - accuracy: 0.5120 - val_loss: 0.3702 - val_accuracy: 0.5002
# Epoch 84/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2504 - accuracy: 0.5084 - val_loss: 0.3736 - val_accuracy: 0.5002
# Epoch 85/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2508 - accuracy: 0.5088 - val_loss: 0.3683 - val_accuracy: 0.5000
# Epoch 86/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2506 - accuracy: 0.5112 - val_loss: 0.3695 - val_accuracy: 0.5005
# Epoch 87/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2498 - accuracy: 0.5143 - val_loss: 0.3695 - val_accuracy: 0.5005
# Epoch 88/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2498 - accuracy: 0.5227 - val_loss: 0.3709 - val_accuracy: 0.5003
# Epoch 89/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2507 - accuracy: 0.5109 - val_loss: 0.3684 - val_accuracy: 0.5007
# Epoch 90/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2503 - accuracy: 0.5122 - val_loss: 0.3678 - val_accuracy: 0.5002
# Epoch 91/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2497 - accuracy: 0.5127 - val_loss: 0.3710 - val_accuracy: 0.5003
# Epoch 92/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2497 - accuracy: 0.5175 - val_loss: 0.3703 - val_accuracy: 0.5003
# Epoch 93/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2499 - accuracy: 0.5147 - val_loss: 0.3709 - val_accuracy: 0.5002
# Epoch 94/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2498 - accuracy: 0.5168 - val_loss: 0.3659 - val_accuracy: 0.5007
# Epoch 95/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2495 - accuracy: 0.5177 - val_loss: 0.3663 - val_accuracy: 0.5005
# Epoch 96/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2499 - accuracy: 0.5104 - val_loss: 0.3703 - val_accuracy: 0.5003
# Epoch 97/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2495 - accuracy: 0.5155 - val_loss: 0.3690 - val_accuracy: 0.5002
# Epoch 98/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2504 - accuracy: 0.5120 - val_loss: 0.3739 - val_accuracy: 0.5005
# Epoch 99/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2495 - accuracy: 0.5139 - val_loss: 0.3736 - val_accuracy: 0.5003
# Epoch 100/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2490 - accuracy: 0.5212 - val_loss: 0.3740 - val_accuracy: 0.5007
# Epoch 101/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2495 - accuracy: 0.5177 - val_loss: 0.3718 - val_accuracy: 0.4998
# Epoch 102/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2500 - accuracy: 0.5126 - val_loss: 0.3692 - val_accuracy: 0.5007
# Epoch 103/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2494 - accuracy: 0.5162 - val_loss: 0.3714 - val_accuracy: 0.5008
# Epoch 104/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2499 - accuracy: 0.5157 - val_loss: 0.3626 - val_accuracy: 0.4998
# Epoch 105/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2495 - accuracy: 0.5163 - val_loss: 0.3669 - val_accuracy: 0.5007
# Epoch 106/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2499 - accuracy: 0.5180 - val_loss: 0.3679 - val_accuracy: 0.5005
# Epoch 107/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2486 - accuracy: 0.5280 - val_loss: 0.3696 - val_accuracy: 0.5003
# Epoch 108/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2492 - accuracy: 0.5142 - val_loss: 0.3679 - val_accuracy: 0.5005
# Epoch 109/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.
500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2395 - accuracy: 0.5769 - val_loss: 0.3132 - val_accuracy: 0.5002
# Epoch 257/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2393 - accuracy: 0.5722 - val_loss: 0.3139 - val_accuracy: 0.4985
# Epoch 258/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2375 - accuracy: 0.5804 - val_loss: 0.3127 - val_accuracy: 0.4992
# Epoch 259/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2388 - accuracy: 0.5767 - val_loss: 0.3131 - val_accuracy: 0.5035
# Epoch 260/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2400 - accuracy: 0.5742 - val_loss: 0.3115 - val_accuracy: 0.5018
# Epoch 261/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2396 - accuracy: 0.5753 - val_loss: 0.3139 - val_accuracy: 0.4995
# Epoch 262/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2391 - accuracy: 0.5773 - val_loss: 0.3096 - val_accuracy: 0.5022
# Epoch 263/500
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2392 - accuracy: 0.5756 - val_loss: 0.3131 - val_accuracy: 0.5000
# Epoch 264/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2400 - accuracy: 0.5717 - val_loss: 0.3117 - val_accuracy: 0.5008
# Epoch 265/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2394 - accuracy: 0.5753 - val_loss: 0.3128 - val_accuracy: 0.4992
# Epoch 266/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2395 - accuracy: 0.5705 - val_loss: 0.3144 - val_accuracy: 0.4993
# Epoch 267/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2375 - accuracy: 0.5792 - val_loss: 0.3126 - val_accuracy: 0.5023
# Epoch 268/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2383 - accuracy: 0.5768 - val_loss: 0.3133 - val_accuracy: 0.5012
# Epoch 269/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2382 - accuracy: 0.5795 - val_loss: 0.3119 - val_accuracy: 0.4997
# Epoch 270/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2386 - accuracy: 0.5746 - val_loss: 0.3153 - val_accuracy: 0.4978
# Epoch 271/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2375 - accuracy: 0.5825 - val_loss: 0.3062 - val_accuracy: 0.5007
# Epoch 272/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2391 - accuracy: 0.5750 - val_loss: 0.3062 - val_accuracy: 0.5000
# Epoch 273/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2377 - accuracy: 0.5774 - val_loss: 0.3103 - val_accuracy: 0.5028
# Epoch 274/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2370 - accuracy: 0.5845 - val_loss: 0.3121 - val_accuracy: 0.4982
# Epoch 275/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2362 - accuracy: 0.5900 - val_loss: 0.3094 - val_accuracy: 0.4982
# Epoch 276/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2362 - accuracy: 0.5871 - val_loss: 0.3050 - val_accuracy: 0.4993
# Epoch 277/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2374 - accuracy: 0.5795 - val_loss: 0.3152 - val_accuracy: 0.5017
# Epoch 278/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2356 - accuracy: 0.5912 - val_loss: 0.3083 - val_accuracy: 0.5008
# Epoch 279/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2369 - accuracy: 0.5773 - val_loss: 0.3107 - val_accuracy: 0.4965
# Epoch 280/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2363 - accuracy: 0.5865 - val_loss: 0.3127 - val_accuracy: 0.4977
# Epoch 281/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2362 - accuracy: 0.5854 - val_loss: 0.3056 - val_accuracy: 0.4983
# Epoch 282/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2362 - accuracy: 0.5844 - val_loss: 0.3095 - val_accuracy: 0.4973
# Epoch 283/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2344 - accuracy: 0.5923 - val_loss: 0.3045 - val_accuracy: 0.4967
# Epoch 284/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2354 - accuracy: 0.5874 - val_loss: 0.3067 - val_accuracy: 0.4992
# Epoch 285/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2367 - accuracy: 0.5863 - val_loss: 0.3063 - val_accuracy: 0.4967
# Epoch 286/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.
500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2050 - accuracy: 0.6833 - val_loss: 0.2913 - val_accuracy: 0.4987
# Epoch 492/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2078 - accuracy: 0.6783 - val_loss: 0.2937 - val_accuracy: 0.4948
# Epoch 493/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2078 - accuracy: 0.6767 - val_loss: 0.2886 - val_accuracy: 0.5002
# Epoch 494/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2062 - accuracy: 0.6775 - val_loss: 0.2912 - val_accuracy: 0.4977
# Epoch 495/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2066 - accuracy: 0.6780 - val_loss: 0.2927 - val_accuracy: 0.4922
# Epoch 496/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2041 - accuracy: 0.6851 - val_loss: 0.2941 - val_accuracy: 0.4943
# Epoch 497/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2060 - accuracy: 0.6833 - val_loss: 0.2926 - val_accuracy: 0.4912
# Epoch 498/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2073 - accuracy: 0.6770 - val_loss: 0.2919 - val_accuracy: 0.4932
# Epoch 499/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2067 - accuracy: 0.6796 - val_loss: 0.2970 - val_accuracy: 0.4895
# Epoch 500/500
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2044 - accuracy: 0.6831 - val_loss: 0.2932 - val_accuracy: 0.4935

# %% [markdown]
# ## Compute accuracy

# %%
def compute_accuracy(y_true, y_pred):
    '''Compute classification accuracy with a fixed threshold on distances.
    '''
    pred = y_pred.ravel() < 0.5
    return np.mean(pred == y_true)

# %%
loss = model.evaluate(x=[ts_pairs[:,0],ts_pairs[:,1]], y=ts_y)

y_pred_train = model.predict([tr_pairs[:,0], tr_pairs[:,1]])
train_accuracy = compute_accuracy(tr_y, y_pred_train)

y_pred_test = model.predict([ts_pairs[:,0], ts_pairs[:,1]])
test_accuracy = compute_accuracy(ts_y, y_pred_test)

print("Loss = {}, Train Accuracy = {} Test Accuracy = {}".format(loss, train_accuracy, test_accuracy))
# Out:
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2932 - accuracy: 0.4935
# 437/437 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# Loss = [0.2931932806968689, 0.4934913218021393], Train Accuracy = 0.5 Test Accuracy = 0.5

# %% [markdown]
# ## Plot training results

# %%
import matplotlib.pyplot as plt

def plot_metrics(title="Training result"):
    fig, ax = plt.subplots(figsize=((10, 10)))
    ax.set_title(title)
    ax.plot(history.history['loss'], label="Loss")
    ax.plot(history.history['val_loss'], label="Validation Loss")
    ax.plot(history.history['accuracy'], label="Accuracy")
    ax.plot(history.history['val_accuracy'], label="Validation Accuracy")
    ax.grid()
    ax.legend(prop={'size': 15})

plot_metrics()

# %% [markdown]
# ## Display the most and the least similar song from training

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

min_dif = np.min(y_pred_train)
min_ind = np.where(y_pred_train == min_dif)[0][0]
max_dif = np.max(y_pred_train)
max_ind = np.where(y_pred_train == max_dif)[0][0]

fig, ax = plt.subplots(2, 2, sharex=True, figsize=(20, 10))
fig.suptitle("Training result", fontsize=20)
img0 = librosa.display.specshow(tr_pairs[min_ind,0], x_axis="time", ax=ax[0,0])
fig.colorbar(img0, ax=[ax[0,0]])
ax[0,0].set_title(f"Difference between songs is {min_dif:.4f}\n\nSong is {tr_names[min_ind][0]}")

img1 = librosa.display.specshow(tr_pairs[min_ind,1], x_axis='time', ax=ax[1,0])
fig.colorbar(img1, ax=[ax[1,0]])
ax[1,0].set_title(f"Song is {tr_names[min_ind][1]}")

img2 = librosa.display.specshow(tr_pairs[max_ind,0], x_axis='time', ax=ax[0,1])
fig.colorbar(img2, ax=[ax[0,1]])
ax[0,1].set_title(f"Difference between songs is {max_dif:.4f}\n\nSong is {tr_names[max_ind][0]}")

img3 = librosa.display.specshow(tr_pairs[max_ind,1], x_axis='time', ax=ax[1,1])
fig.colorbar(img3, ax=[ax[1,1]])
ax[1,1].set_title(f"Song is {tr_names[max_ind][1]}")
# Out:
# Text(0.5, 1.0, 'Song is rock.00023.wav')

# %% [markdown]
# ## Display the most and the least similar song from test

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

min_dif = np.min(y_pred_test)
min_ind = np.where(y_pred_test == min_dif)[0][0]
max_dif = np.max(y_pred_test)
max_ind = np.where(y_pred_test == max_dif)[0][0]

fig, ax = plt.subplots(2, 2, sharex=True, figsize=(20, 10))
fig.suptitle("Test result", fontsize=20)
img0 = librosa.display.specshow(ts_pairs[min_ind,0], x_axis="time", ax=ax[0,0])
fig.colorbar(img0, ax=[ax[0,0]])
ax[0,0].set_title(f"Difference between songs is {min_dif:.4f}\n\nSong is {ts_names[min_ind][0]}")

img1 = librosa.display.specshow(ts_pairs[min_ind,1], x_axis='time', ax=ax[1,0])
fig.colorbar(img1, ax=[ax[1,0]])
ax[1,0].set_title(f"Song is {ts_names[min_ind][1]}")

img2 = librosa.display.specshow(ts_pairs[max_ind,0], x_axis='time', ax=ax[0,1])
fig.colorbar(img2, ax=[ax[0,1]])
ax[0,1].set_title(f"Difference between songs is {max_dif:.4f}\n\nSong is {ts_names[max_ind][0]}")

img3 = librosa.display.specshow(ts_pairs[max_ind,1], x_axis='time', ax=ax[1,1])
fig.colorbar(img3, ax=[ax[1,1]])
ax[1,1].set_title(f"Song is {ts_names[max_ind][1]}")
# Out:
# Text(0.5, 1.0, 'Song is pop.00038.wav')

# %% [markdown]
# ## Save pretrained model

# %%
model.save('/content/drive/MyDrive/DL/Project/Model')

# %% [markdown]
# ## Make recommendations

# %%
def recommendation_list(song_name, num_songs=10):
  fav_song = song_name
  fav_pairs = [[np.array([0]), [fav_song, fav_song]]]
  for i in range(len(tr_names)):
    if (fav_song == tr_names[i][0]) ^ (fav_song == tr_names[i][1]):
      fav_pairs.append([y_pred_train[i], tr_names[i]])
  for i in range(len(ts_names)):
    if (fav_song == ts_names[i][0]) ^ (fav_song == ts_names[i][1]):
      fav_pairs.append([y_pred_test[i], ts_names[i]])
  fav_pairs = sorted(fav_pairs, key=lambda l:l[0])
  recommended_list = [pair[1][0] if pair[1][0] != fav_song else pair[1][1] for pair in fav_pairs[:num_songs]]
  return recommended_list

# %%
recommendation_list('metal.00024.wav')
# Out:
# ['metal.00024.wav',
#  'metal.00054.wav',
#  'pop.00015.wav',
#  'metal.00081.wav',
#  'metal.00059.wav',
#  'metal.00062.wav',
#  'disco.00017.wav',
#  'reggae.00058.wav',
#  'country.00067.wav',
#  'metal.00057.wav']
