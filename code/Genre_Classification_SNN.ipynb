# %% [markdown]
# ## Connect to Google Drive to download JSON file with preprocessed data

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load data from preprocessed JSON

# %%
import json

def load_data(json_path):
  with open(json_path, "r") as fp:
        data = json.load(fp)

  X = (data['mfcc']) # Contains name of the song and corresponding MFCC's
  y = (data['labels']) # Contains genre labels of each song
  return X, y

json_path = '/content/drive/MyDrive/DL/Project/Data/preprocess/mel_specs.json'
orig_x_data, orig_y_data = load_data(json_path)

# %% [markdown]
# ## Refactor data into numpy array of spectrograms

# %%
import numpy as np
import sys

x_data, y_data = [], []
for i in range(len(orig_x_data)):
  x_d = orig_x_data[i]
  for j in range(len(x_d)):
    x_data.append([x_d[j][0][0], np.array(x_d[j][1]).T])
    y_data.append(orig_y_data[i])
X = x_data
y = np.array(y_data)

# %% [markdown]
# ## Split data into train and test sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ## Divide data into pairs

# %%
def create_pairs(plots, labels):
  pair_plots, pair_labels, pair_names = [], [], []
  num_labels = len(np.unique(labels)) # number of labels
  
  # Get indices of songs of each genre
  indices = [np.where(labels == i)[0] for i in range(num_labels)]
  
  for idx1 in range(len(plots)):
    # Get the current song name, MFCC and genre
    name1 = plots[idx1][0]
    plot1 = plots[idx1][1]
    label1 = labels[idx1]

    # Take random MFCC of other song with the same genre
    idx2 = np.random.choice(indices[label1])
    name2 = plots[idx2][0]
    plot2 = plots[idx2][1]

    # Add pair
    pair_plots.append([plot1, plot2])
    pair_labels.append([1])
    pair_names.append([name1, name2])

    # Take random MFCC of other song with different genre
    idx3 = np.where(labels != label1)[0]
    rand_idx3 = np.random.choice(idx3)
    name3 = plots[rand_idx3][0]
    plot3 = plots[rand_idx3][1]

    # Add pair
    pair_plots.append([plot1, plot3])
    pair_labels.append([0])
    pair_names.append([name1, name3])
  return np.array(pair_plots), np.array(pair_labels), pair_names

tr_pairs, tr_y, tr_names = create_pairs(X_train, y_train)
ts_pairs, ts_y, ts_names = create_pairs(X_test, y_test)

# %% [markdown]
# ## Initialize network

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, Lambda, Conv2D, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import RMSprop, SGD, Adam
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K

def initialize_base_network(input_shape, embeddingDim=48):
    input = Input(shape=input_shape, name="base_input")
    x = Flatten(name="flatten_input")(input)
    x = Dense(256, activation='sigmoid', name="first_base_dense")(x)
    x = Dropout(0.1, name="first_dropout")(x)
    x = Dense(256, activation='sigmoid', name="second_base_dense")(x)
    x = Dropout(0.1, name="second_dropout")(x)
    x = Dense(256, activation='sigmoid', name="third_base_dense")(x)

    model = Model(inputs=input, outputs=x)
    print(model.summary())
    return model

def euclidean_distance(vects):
    x, y = vects
    sum_square = K.sum(K.square(x - y), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sum_square, K.epsilon()))


def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
shape = (13,130,1)
base_network = initialize_base_network(input_shape=shape)
# Create the left input and point to the base network
input_a = Input(shape=shape, name="left_input")
vect_output_a = base_network(input_a)

# Create the right input and point to the base network
input_b = Input(shape=shape, name="right_input")
vect_output_b = base_network(input_b)

# Measure the similarity of the two vector outputs
output = Lambda(euclidean_distance, name="output_layer", output_shape=eucl_dist_output_shape)([vect_output_a, vect_output_b])

# Specify the inputs and output of the model
model = Model([input_a, input_b], output)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  base_input (InputLayer)     [(None, 13, 130, 1)]      0
#
#  flatten_input (Flatten)     (None, 1690)              0
#
#  first_base_dense (Dense)    (None, 256)               432896
#
#  first_dropout (Dropout)     (None, 256)               0
#
#  second_base_dense (Dense)   (None, 256)               65792
#
#  second_dropout (Dropout)    (None, 256)               0
#
#  third_base_dense (Dense)    (None, 256)               65792
#
# =================================================================
# Total params: 564,480
# Trainable params: 564,480
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Single network representation

# %%
plot_model(base_network, show_shapes=True, show_layer_names=True, to_file='base-model.png')

# %% [markdown]
# ### Siamese netowrk representation

# %%
plot_model(model, show_shapes=True, show_layer_names=True, to_file='outer-model.png')

# %% [markdown]
# ## Train model

# %%
tr_y = tf.cast(tr_y, tf.float32)
ts_y = tf.cast(ts_y, tf.float32)
rms = RMSprop(learning_rate=0.0001)
model.compile(loss='mse', optimizer=rms, metrics=['accuracy'])
history = model.fit([tr_pairs[:,0], tr_pairs[:,1]], tr_y, epochs=100, batch_size=128, validation_data=([ts_pairs[:,0], ts_pairs[:,1]], ts_y))
# Out:
# Epoch 1/100
# 110/110 [==============================] - 2s 8ms/step - loss: 0.3251 - accuracy: 0.4995 - val_loss: 0.4078 - val_accuracy: 0.4998
# Epoch 2/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2546 - accuracy: 0.4944 - val_loss: 0.4092 - val_accuracy: 0.4998
# Epoch 3/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2533 - accuracy: 0.4946 - val_loss: 0.4017 - val_accuracy: 0.4997
# Epoch 4/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2523 - accuracy: 0.4951 - val_loss: 0.4019 - val_accuracy: 0.4998
# Epoch 5/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2526 - accuracy: 0.4960 - val_loss: 0.4036 - val_accuracy: 0.5000
# Epoch 6/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2525 - accuracy: 0.4926 - val_loss: 0.3931 - val_accuracy: 0.5000
# Epoch 7/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2529 - accuracy: 0.4946 - val_loss: 0.3963 - val_accuracy: 0.5000
# Epoch 8/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2526 - accuracy: 0.4936 - val_loss: 0.3994 - val_accuracy: 0.5000
# Epoch 9/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2519 - accuracy: 0.5025 - val_loss: 0.4002 - val_accuracy: 0.5000
# Epoch 10/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2525 - accuracy: 0.4969 - val_loss: 0.3963 - val_accuracy: 0.5000
# Epoch 11/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2519 - accuracy: 0.4989 - val_loss: 0.4013 - val_accuracy: 0.5000
# Epoch 12/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2524 - accuracy: 0.4964 - val_loss: 0.3950 - val_accuracy: 0.5000
# Epoch 13/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2524 - accuracy: 0.4948 - val_loss: 0.3934 - val_accuracy: 0.5000
# Epoch 14/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2523 - accuracy: 0.4938 - val_loss: 0.3953 - val_accuracy: 0.5000
# Epoch 15/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2518 - accuracy: 0.5049 - val_loss: 0.3949 - val_accuracy: 0.5000
# Epoch 16/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2525 - accuracy: 0.4961 - val_loss: 0.3895 - val_accuracy: 0.5000
# Epoch 17/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2519 - accuracy: 0.4988 - val_loss: 0.3959 - val_accuracy: 0.5000
# Epoch 18/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2517 - accuracy: 0.5011 - val_loss: 0.3951 - val_accuracy: 0.5000
# Epoch 19/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2520 - accuracy: 0.5005 - val_loss: 0.3982 - val_accuracy: 0.5000
# Epoch 20/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2518 - accuracy: 0.4980 - val_loss: 0.4011 - val_accuracy: 0.5000
# Epoch 21/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2517 - accuracy: 0.5019 - val_loss: 0.3983 - val_accuracy: 0.5000
# Epoch 22/100
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2522 - accuracy: 0.4959 - val_loss: 0.3969 - val_accuracy: 0.5000
# Epoch 23/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2517 - accuracy: 0.5013 - val_loss: 0.3962 - val_accuracy: 0.5000
# Epoch 24/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2516 - accuracy: 0.4983 - val_loss: 0.3933 - val_accuracy: 0.5000
# Epoch 25/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2512 - accuracy: 0.5001 - val_loss: 0.3902 - val_accuracy: 0.5000
# Epoch 26/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2518 - accuracy: 0.4951 - val_loss: 0.3859 - val_accuracy: 0.5000
# Epoch 27/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2519 - accuracy: 0.4993 - val_loss: 0.3832 - val_accuracy: 0.5000
# Epoch 28/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2518 - accuracy: 0.4998 - val_loss: 0.3914 - val_accuracy: 0.5000
# Epoch 29/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2523 - accuracy: 0.4959 - val_loss: 0.3899 - val_accuracy: 0.5000
# Epoch 30/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2518 - accuracy: 0.5046 - val_loss: 0.3908 - val_accuracy: 0.5000
# Epoch 31/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2519 - accuracy: 0.4973 - val_loss: 0.3959 - val_accuracy: 0.5000
# Epoch 32/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2510 - accuracy: 0.5035 - val_loss: 0.3939 - val_accuracy: 0.5000
# Epoch 33/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2521 - accuracy: 0.4951 - val_loss: 0.3952 - val_accuracy: 0.5000
# Epoch 34/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2513 - accuracy: 0.5101 - val_loss: 0.3929 - val_accuracy: 0.5000
# Epoch 35/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2520 - accuracy: 0.4982 - val_loss: 0.3954 - val_accuracy: 0.5000
# Epoch 36/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2517 - accuracy: 0.4993 - val_loss: 0.3887 - val_accuracy: 0.5000
# Epoch 37/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2514 - accuracy: 0.5037 - val_loss: 0.3917 - val_accuracy: 0.5000
# Epoch 38/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2524 - accuracy: 0.4981 - val_loss: 0.3924 - val_accuracy: 0.5000
# Epoch 39/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2516 - accuracy: 0.5004 - val_loss: 0.3926 - val_accuracy: 0.5000
# Epoch 40/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2515 - accuracy: 0.5007 - val_loss: 0.3927 - val_accuracy: 0.5000
# Epoch 41/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2515 - accuracy: 0.5027 - val_loss: 0.3902 - val_accuracy: 0.5000
# Epoch 42/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2514 - accuracy: 0.5046 - val_loss: 0.3858 - val_accuracy: 0.5000
# Epoch 43/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2512 - accuracy: 0.5077 - val_loss: 0.3821 - val_accuracy: 0.5000
# Epoch 44/100
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2513 - accuracy: 0.5039 - val_loss: 0.3816 - val_accuracy: 0.5000
# Epoch 45/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2522 - accuracy: 0.4933 - val_loss: 0.3831 - val_accuracy: 0.5000
# Epoch 46/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2512 - accuracy: 0.5056 - val_loss: 0.3841 - val_accuracy: 0.5000
# Epoch 47/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2510 - accuracy: 0.5078 - val_loss: 0.3833 - val_accuracy: 0.5000
# Epoch 48/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2511 - accuracy: 0.5046 - val_loss: 0.3856 - val_accuracy: 0.5002
# Epoch 49/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2516 - accuracy: 0.5011 - val_loss: 0.3850 - val_accuracy: 0.5000
# Epoch 50/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2514 - accuracy: 0.5030 - val_loss: 0.3877 - val_accuracy: 0.5002
# Epoch 51/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2513 - accuracy: 0.5033 - val_loss: 0.3860 - val_accuracy: 0.5000
# Epoch 52/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2519 - accuracy: 0.4978 - val_loss: 0.3832 - val_accuracy: 0.5000
# Epoch 53/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2506 - accuracy: 0.5121 - val_loss: 0.3815 - val_accuracy: 0.5000
# Epoch 54/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2511 - accuracy: 0.5074 - val_loss: 0.3875 - val_accuracy: 0.5002
# Epoch 55/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2499 - accuracy: 0.5149 - val_loss: 0.3832 - val_accuracy: 0.5000
# Epoch 56/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2513 - accuracy: 0.5078 - val_loss: 0.3835 - val_accuracy: 0.5002
# Epoch 57/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2510 - accuracy: 0.5072 - val_loss: 0.3792 - val_accuracy: 0.5000
# Epoch 58/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2507 - accuracy: 0.5078 - val_loss: 0.3828 - val_accuracy: 0.5000
# Epoch 59/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2510 - accuracy: 0.5065 - val_loss: 0.3849 - val_accuracy: 0.5003
# Epoch 60/100
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2508 - accuracy: 0.5100 - val_loss: 0.3803 - val_accuracy: 0.5002
# Epoch 61/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2507 - accuracy: 0.5094 - val_loss: 0.3857 - val_accuracy: 0.5000
# Epoch 62/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2510 - accuracy: 0.5083 - val_loss: 0.3812 - val_accuracy: 0.5000
# Epoch 63/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2507 - accuracy: 0.5071 - val_loss: 0.3796 - val_accuracy: 0.5002
# Epoch 64/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2503 - accuracy: 0.5193 - val_loss: 0.3792 - val_accuracy: 0.4998
# Epoch 65/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2505 - accuracy: 0.5093 - val_loss: 0.3767 - val_accuracy: 0.5000
# Epoch 66/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2506 - accuracy: 0.5064 - val_loss: 0.3771 - val_accuracy: 0.5000
# Epoch 67/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2505 - accuracy: 0.5063 - val_loss: 0.3745 - val_accuracy: 0.5000
# Epoch 68/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2508 - accuracy: 0.5060 - val_loss: 0.3678 - val_accuracy: 0.5003
# Epoch 69/100
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2494 - accuracy: 0.5197 - val_loss: 0.3653 - val_accuracy: 0.5002
# Epoch 70/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2505 - accuracy: 0.5109 - val_loss: 0.3675 - val_accuracy: 0.5000
# Epoch 71/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2502 - accuracy: 0.5163 - val_loss: 0.3655 - val_accuracy: 0.5002
# Epoch 72/100
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2499 - accuracy: 0.5179 - val_loss: 0.3673 - val_accuracy: 0.5002
# Epoch 73/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2507 - accuracy: 0.5063 - val_loss: 0.3704 - val_accuracy: 0.5000
# Epoch 74/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2504 - accuracy: 0.5092 - val_loss: 0.3733 - val_accuracy: 0.5000
# Epoch 75/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.2498 - accuracy: 0.5144 - val_loss: 0.3722 - val_accuracy: 0.5002
# Epoch 76/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.2500 - accuracy: 0.5145 - val_loss: 0.3697 - val_accuracy: 0.5002
# Epoch 77/100
# 110/110 [==============================] - 1s 9ms/step - loss: 0.2499 - accuracy: 0.5152 - val_loss: 0.3714 - val_accuracy: 0.5005
# Epoch 78/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2499 - accuracy: 0.5174 - val_loss: 0.3750 - val_accuracy: 0.5005
# Epoch 79/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2500 - accuracy: 0.5129 - val_loss: 0.3719 - val_accuracy: 0.5010
# Epoch 80/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2503 - accuracy: 0.5085 - val_loss: 0.3704 - val_accuracy: 0.5005
# Epoch 81/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2501 - accuracy: 0.5100 - val_loss: 0.3695 - val_accuracy: 0.5012
# Epoch 82/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2491 - accuracy: 0.5200 - val_loss: 0.3659 - val_accuracy: 0.5012
# Epoch 83/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2495 - accuracy: 0.5114 - val_loss: 0.3673 - val_accuracy: 0.5017
# Epoch 84/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2494 - accuracy: 0.5202 - val_loss: 0.3711 - val_accuracy: 0.5007
# Epoch 85/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2493 - accuracy: 0.5162 - val_loss: 0.3718 - val_accuracy: 0.5005
# Epoch 86/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2495 - accuracy: 0.5174 - val_loss: 0.3722 - val_accuracy: 0.5013
# Epoch 87/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2494 - accuracy: 0.5240 - val_loss: 0.3672 - val_accuracy: 0.5013
# Epoch 88/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2493 - accuracy: 0.5172 - val_loss: 0.3663 - val_accuracy: 0.5005
# Epoch 89/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2494 - accuracy: 0.5210 - val_loss: 0.3674 - val_accuracy: 0.5003
# Epoch 90/100
# 110/110 [==============================] - 1s 7ms/step - loss: 0.2492 - accuracy: 0.5172 - val_loss: 0.3685 - val_accuracy: 0.5002
# Epoch 91/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2484 - accuracy: 0.5235 - val_loss: 0.3692 - val_accuracy: 0.5007
# Epoch 92/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2486 - accuracy: 0.5252 - val_loss: 0.3677 - val_accuracy: 0.5010
# Epoch 93/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2483 - accuracy: 0.5264 - val_loss: 0.3585 - val_accuracy: 0.5008
# Epoch 94/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2490 - accuracy: 0.5233 - val_loss: 0.3590 - val_accuracy: 0.5012
# Epoch 95/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2479 - accuracy: 0.5274 - val_loss: 0.3580 - val_accuracy: 0.5007
# Epoch 96/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2488 - accuracy: 0.5259 - val_loss: 0.3559 - val_accuracy: 0.5012
# Epoch 97/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2492 - accuracy: 0.5166 - val_loss: 0.3573 - val_accuracy: 0.5015
# Epoch 98/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2486 - accuracy: 0.5198 - val_loss: 0.3576 - val_accuracy: 0.5010
# Epoch 99/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2484 - accuracy: 0.5236 - val_loss: 0.3561 - val_accuracy: 0.5005
# Epoch 100/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.2485 - accuracy: 0.5242 - val_loss: 0.3532 - val_accuracy: 0.5003

# %% [markdown]
# ## Compute accuracy

# %%
def compute_accuracy(y_true, y_pred):
    '''Compute classification accuracy with a fixed threshold on distances.
    '''
    pred = y_pred.ravel() < 0.5
    return np.mean(pred == y_true)

# %%
loss = model.evaluate(x=[ts_pairs[:,0],ts_pairs[:,1]], y=ts_y)

y_pred_train = model.predict([tr_pairs[:,0], tr_pairs[:,1]])
train_accuracy = compute_accuracy(tr_y, y_pred_train)

y_pred_test = model.predict([ts_pairs[:,0], ts_pairs[:,1]])
test_accuracy = compute_accuracy(ts_y, y_pred_test)

print("Loss = {}, Train Accuracy = {} Test Accuracy = {}".format(loss, train_accuracy, test_accuracy))
# Out:
# 188/188 [==============================] - 1s 3ms/step - loss: 0.3532 - accuracy: 0.5003
# 437/437 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# Loss = [0.35318851470947266, 0.5003337860107422], Train Accuracy = 0.5 Test Accuracy = 0.5

# %% [markdown]
# ## Plot training results

# %%
import matplotlib.pyplot as plt

def plot_metrics(title="Training result"):
    fig, ax = plt.subplots(figsize=((10, 10)))
    ax.set_title(title)
    ax.plot(history.history['loss'], label="Loss")
    ax.plot(history.history['val_loss'], label="Validation Loss")
    ax.plot(history.history['accuracy'], label="Accuracy")
    ax.plot(history.history['val_accuracy'], label="Validation Accuracy")
    ax.grid()
    ax.legend(prop={'size': 15})

plot_metrics()

# %% [markdown]
# ## Display the most and the least similar song from training

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

min_dif = np.min(y_pred_train)
min_ind = np.where(y_pred_train == min_dif)[0][0]
max_dif = np.max(y_pred_train)
max_ind = np.where(y_pred_train == max_dif)[0][0]

fig, ax = plt.subplots(2, 2, sharex=True, figsize=(20, 10))
fig.suptitle("Training result", fontsize=20)
img0 = librosa.display.specshow(tr_pairs[min_ind,0], x_axis="time", ax=ax[0,0])
fig.colorbar(img0, ax=[ax[0,0]])
ax[0,0].set_title(f"Difference between songs is {min_dif:.4f}\n\nSong is {tr_names[min_ind][0]}")

img1 = librosa.display.specshow(tr_pairs[min_ind,1], x_axis='time', ax=ax[1,0])
fig.colorbar(img1, ax=[ax[1,0]])
ax[1,0].set_title(f"Song is {tr_names[min_ind][1]}")

img2 = librosa.display.specshow(tr_pairs[max_ind,0], x_axis='time', ax=ax[0,1])
fig.colorbar(img2, ax=[ax[0,1]])
ax[0,1].set_title(f"Difference between songs is {max_dif:.4f}\n\nSong is {tr_names[max_ind][0]}")

img3 = librosa.display.specshow(tr_pairs[max_ind,1], x_axis='time', ax=ax[1,1])
fig.colorbar(img3, ax=[ax[1,1]])
ax[1,1].set_title(f"Song is {tr_names[max_ind][1]}")
# Out:
# Text(0.5, 1.0, 'Song is pop.00037.wav')

# %% [markdown]
# ## Display the most and the least similar song from test

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

min_dif = np.min(y_pred_test)
min_ind = np.where(y_pred_test == min_dif)[0][0]
max_dif = np.max(y_pred_test)
max_ind = np.where(y_pred_test == max_dif)[0][0]

fig, ax = plt.subplots(2, 2, sharex=True, figsize=(20, 10))
fig.suptitle("Test result", fontsize=20)
img0 = librosa.display.specshow(ts_pairs[min_ind,0], x_axis="time", ax=ax[0,0])
fig.colorbar(img0, ax=[ax[0,0]])
ax[0,0].set_title(f"Difference between songs is {min_dif:.4f}\n\nSong is {ts_names[min_ind][0]}")

img1 = librosa.display.specshow(ts_pairs[min_ind,1], x_axis='time', ax=ax[1,0])
fig.colorbar(img1, ax=[ax[1,0]])
ax[1,0].set_title(f"Song is {ts_names[min_ind][1]}")

img2 = librosa.display.specshow(ts_pairs[max_ind,0], x_axis='time', ax=ax[0,1])
fig.colorbar(img2, ax=[ax[0,1]])
ax[0,1].set_title(f"Difference between songs is {max_dif:.4f}\n\nSong is {ts_names[max_ind][0]}")

img3 = librosa.display.specshow(ts_pairs[max_ind,1], x_axis='time', ax=ax[1,1])
fig.colorbar(img3, ax=[ax[1,1]])
ax[1,1].set_title(f"Song is {ts_names[max_ind][1]}")
# Out:
# Text(0.5, 1.0, 'Song is disco.00015.wav')

# %% [markdown]
# ## Save pretrained model

# %%
model.save('/content/drive/MyDrive/DL/Project/Model')

# %% [markdown]
# ## Make recommendations

# %%
def recommendation_list(song_name, num_songs=10):
  fav_song = song_name
  fav_pairs = [[np.array([0]), [fav_song, fav_song]]]
  for i in range(len(tr_names)):
    if (fav_song == tr_names[i][0]) ^ (fav_song == tr_names[i][1]):
      fav_pairs.append([y_pred_train[i], tr_names[i]])
  for i in range(len(ts_names)):
    if (fav_song == ts_names[i][0]) ^ (fav_song == ts_names[i][1]):
      fav_pairs.append([y_pred_test[i], ts_names[i]])
  fav_pairs = sorted(fav_pairs, key=lambda l:l[0])
  recommended_list = [pair[1][0] if pair[1][0] != fav_song else pair[1][1] for pair in fav_pairs[:num_songs]]
  return recommended_list

# %%
recommendation_list('metal.00024.wav')
# Out:
# ['metal.00024.wav',
#  'metal.00020.wav',
#  'metal.00046.wav',
#  'metal.00061.wav',
#  'metal.00081.wav',
#  'pop.00008.wav',
#  'reggae.00017.wav',
#  'metal.00084.wav',
#  'metal.00097.wav',
#  'metal.00045.wav']
