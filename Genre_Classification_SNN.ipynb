# %% [markdown]
# ## Connect to Google Drive to download JSON file with preprocessed data

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# ## Load data from preprocessed JSON

# %%
import json

def load_data(json_path):
  with open(json_path, "r") as fp:
        data = json.load(fp)

  X = (data['mfcc'])
  y = (data['labels'])
  return X, y

json_path = '/content/drive/MyDrive/DL/Project/Data/preprocess/mel_specs.json'
orig_x_data, orig_y_data = load_data(json_path)

# %% [markdown]
# ## Refactor data into numpy array of spectrograms

# %%
import numpy as np
import sys

x_data, y_data = [], []
for i in range(len(orig_x_data)):
  x_d = orig_x_data[i]
  for j in range(len(x_d)):
    x_data.append([x_d[j][0][0], np.array(x_d[j][1]).T])
    y_data.append(orig_y_data[i])
X = x_data
y = np.array(y_data)

# %% [markdown]
# ## Split data into train and test sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
len(X_train)
# Out:
# 6990

# %% [markdown]
# ## Divide data into pairs

# %%
def create_pairs(plots, labels):
  pair_plots, pair_labels, pair_names = [], [], []
  num_labels = len(np.unique(labels))
  
  indices = [np.where(labels == i)[0] for i in range(num_labels)]
  
  for idx1 in range(len(plots)):
    name1 = plots[idx1][0]
    plot1 = plots[idx1][1]
    label1 = labels[idx1]

    idx2 = np.random.choice(indices[label1])
    name2 = plots[idx2][0]
    plot2 = plots[idx2][1]

    pair_plots.append([plot1, plot2])
    pair_labels.append([1])
    pair_names.append([name1, name2])

    idx3 = np.where(labels != label1)[0]
    rand_idx3 = np.random.choice(idx3)
    name3 = plots[rand_idx3][0]
    plot3 = plots[rand_idx3][1]

    pair_plots.append([plot1, plot3])
    pair_labels.append([0])
    pair_names.append([name1, name3])
  return np.array(pair_plots), np.array(pair_labels), pair_names

tr_pairs, tr_y, tr_names = create_pairs(X_train, y_train)
ts_pairs, ts_y, ts_names = create_pairs(X_test, y_test)

# %% [markdown]
# ## Initialize network

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, Lambda, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K

def initialize_base_network(input_shape, embeddingDim=48):
    input = Input(shape=input_shape, name="base_input")
    x = Flatten(name="flatten_input")(input)
    x = Dense(1024, activation='sigmoid', name="first_base_dense")(x)
    x = Dropout(0.1, name="first_dropout")(x)
    x = Dense(512, activation='sigmoid', name="second_base_dense")(x)
    x = Dropout(0.1, name="second_dropout")(x)
    x = Dense(256, activation='sigmoid', name="third_base_dense")(x)

    model = Model(inputs=input, outputs=x)
    print(model.summary())
    return model

def euclidean_distance(vects):
    x, y = vects
    sum_square = K.sum(K.square(x - y), axis=1, keepdims=True)
    return K.sqrt(K.maximum(sum_square, K.epsilon()))


def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
shape = (13,130,1)
base_network = initialize_base_network(input_shape=shape)
# create the left input and point to the base network
input_a = Input(shape=shape, name="left_input")
vect_output_a = base_network(input_a)

# create the right input and point to the base network
input_b = Input(shape=shape, name="right_input")
vect_output_b = base_network(input_b)

# measure the similarity of the two vector outputs
output = Lambda(euclidean_distance, name="output_layer", output_shape=eucl_dist_output_shape)([vect_output_a, vect_output_b])

# specify the inputs and output of the model
model = Model([input_a, input_b], output)
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  base_input (InputLayer)     [(None, 13, 130, 1)]      0
#
#  flatten_input (Flatten)     (None, 1690)              0
#
#  first_base_dense (Dense)    (None, 1024)              1731584
#
#  first_dropout (Dropout)     (None, 1024)              0
#
#  second_base_dense (Dense)   (None, 512)               524800
#
#  second_dropout (Dropout)    (None, 512)               0
#
#  third_base_dense (Dense)    (None, 256)               131328
#
# =================================================================
# Total params: 2,387,712
# Trainable params: 2,387,712
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Single netowrk representation

# %%
plot_model(base_network, show_shapes=True, show_layer_names=True, to_file='base-model.png')

# %% [markdown]
# ### Siamese netowrk representation

# %%
plot_model(model, show_shapes=True, show_layer_names=True, to_file='outer-model.png')

# %%
def contrastive_loss_with_margin(margin):
    def contrastive_loss(y_true, y_pred):
        '''Contrastive loss from Hadsell-et-al.'06
        http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
        '''
        square_pred = K.square(y_pred)
        margin_square = K.square(K.maximum(margin - y_pred, 0))
        return K.mean(y_true * square_pred + (1 - y_true) * margin_square)
    return contrastive_loss

# %% [markdown]
# ## Train model

# %%
tr_y = tf.cast(tr_y, tf.float32)
ts_y = tf.cast(ts_y, tf.float32)
rms = RMSprop()
model.compile(loss=contrastive_loss_with_margin(margin=1), optimizer=rms, metrics=['accuracy'])
history = model.fit([tr_pairs[:,0], tr_pairs[:,1]], tr_y[:], epochs=100, batch_size=200, validation_data=([ts_pairs[:,0], ts_pairs[:,1]], ts_y[:]))
# Out:
# Epoch 1/100
# 70/70 [==============================] - 2s 14ms/step - loss: 0.2482 - accuracy: 0.4308 - val_loss: 0.2958 - val_accuracy: 0.4696
# Epoch 2/100
# 70/70 [==============================] - 1s 9ms/step - loss: 0.2332 - accuracy: 0.3969 - val_loss: 0.2456 - val_accuracy: 0.3905
# Epoch 3/100
# 70/70 [==============================] - 1s 9ms/step - loss: 0.2306 - accuracy: 0.3807 - val_loss: 0.2339 - val_accuracy: 0.3715
# Epoch 4/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2291 - accuracy: 0.3773 - val_loss: 0.2470 - val_accuracy: 0.3828
# Epoch 5/100
# 70/70 [==============================] - 1s 9ms/step - loss: 0.2280 - accuracy: 0.3767 - val_loss: 0.2361 - val_accuracy: 0.3635
# Epoch 6/100
# 70/70 [==============================] - 1s 9ms/step - loss: 0.2259 - accuracy: 0.3659 - val_loss: 0.2397 - val_accuracy: 0.3785
# Epoch 7/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2272 - accuracy: 0.3722 - val_loss: 0.2346 - val_accuracy: 0.3660
# Epoch 8/100
# 70/70 [==============================] - 1s 9ms/step - loss: 0.2241 - accuracy: 0.3660 - val_loss: 0.2589 - val_accuracy: 0.4095
# Epoch 9/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2243 - accuracy: 0.3589 - val_loss: 0.2357 - val_accuracy: 0.3627
# Epoch 10/100
# 70/70 [==============================] - 1s 9ms/step - loss: 0.2240 - accuracy: 0.3648 - val_loss: 0.2420 - val_accuracy: 0.3843
# Epoch 11/100
# 70/70 [==============================] - 1s 9ms/step - loss: 0.2237 - accuracy: 0.3634 - val_loss: 0.2295 - val_accuracy: 0.3550
# Epoch 12/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2226 - accuracy: 0.3640 - val_loss: 0.2262 - val_accuracy: 0.3608
# Epoch 13/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2256 - accuracy: 0.3712 - val_loss: 0.2386 - val_accuracy: 0.3747
# Epoch 14/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2234 - accuracy: 0.3666 - val_loss: 0.2387 - val_accuracy: 0.3738
# Epoch 15/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2226 - accuracy: 0.3617 - val_loss: 0.2225 - val_accuracy: 0.3538
# Epoch 16/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2208 - accuracy: 0.3592 - val_loss: 0.2380 - val_accuracy: 0.3700
# Epoch 17/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2225 - accuracy: 0.3608 - val_loss: 0.2410 - val_accuracy: 0.3835
# Epoch 18/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2207 - accuracy: 0.3536 - val_loss: 0.2225 - val_accuracy: 0.3488
# Epoch 19/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2195 - accuracy: 0.3543 - val_loss: 0.2174 - val_accuracy: 0.3415
# Epoch 20/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2203 - accuracy: 0.3573 - val_loss: 0.2295 - val_accuracy: 0.3625
# Epoch 21/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2192 - accuracy: 0.3516 - val_loss: 0.2322 - val_accuracy: 0.3667
# Epoch 22/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2195 - accuracy: 0.3559 - val_loss: 0.2248 - val_accuracy: 0.3551
# Epoch 23/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2176 - accuracy: 0.3513 - val_loss: 0.2243 - val_accuracy: 0.3515
# Epoch 24/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2174 - accuracy: 0.3463 - val_loss: 0.2296 - val_accuracy: 0.3638
# Epoch 25/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2172 - accuracy: 0.3516 - val_loss: 0.2230 - val_accuracy: 0.3558
# Epoch 26/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2168 - accuracy: 0.3446 - val_loss: 0.2388 - val_accuracy: 0.3787
# Epoch 27/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2168 - accuracy: 0.3479 - val_loss: 0.2186 - val_accuracy: 0.3468
# Epoch 28/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2157 - accuracy: 0.3483 - val_loss: 0.2252 - val_accuracy: 0.3543
# Epoch 29/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2177 - accuracy: 0.3529 - val_loss: 0.2172 - val_accuracy: 0.3426
# Epoch 30/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2174 - accuracy: 0.3492 - val_loss: 0.2245 - val_accuracy: 0.3590
# Epoch 31/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2161 - accuracy: 0.3507 - val_loss: 0.2179 - val_accuracy: 0.3423
# Epoch 32/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2169 - accuracy: 0.3413 - val_loss: 0.2270 - val_accuracy: 0.3596
# Epoch 33/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2161 - accuracy: 0.3469 - val_loss: 0.2159 - val_accuracy: 0.3411
# Epoch 34/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2146 - accuracy: 0.3435 - val_loss: 0.2373 - val_accuracy: 0.3833
# Epoch 35/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2145 - accuracy: 0.3417 - val_loss: 0.2208 - val_accuracy: 0.3490
# Epoch 36/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2179 - accuracy: 0.3529 - val_loss: 0.2267 - val_accuracy: 0.3585
# Epoch 37/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2164 - accuracy: 0.3456 - val_loss: 0.2206 - val_accuracy: 0.3433
# Epoch 38/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2158 - accuracy: 0.3491 - val_loss: 0.2356 - val_accuracy: 0.3665
# Epoch 39/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2153 - accuracy: 0.3506 - val_loss: 0.2154 - val_accuracy: 0.3351
# Epoch 40/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2143 - accuracy: 0.3469 - val_loss: 0.2256 - val_accuracy: 0.3555
# Epoch 41/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2147 - accuracy: 0.3444 - val_loss: 0.2229 - val_accuracy: 0.3480
# Epoch 42/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2149 - accuracy: 0.3430 - val_loss: 0.2150 - val_accuracy: 0.3363
# Epoch 43/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2121 - accuracy: 0.3377 - val_loss: 0.2162 - val_accuracy: 0.3426
# Epoch 44/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2114 - accuracy: 0.3409 - val_loss: 0.2165 - val_accuracy: 0.3341
# Epoch 45/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2117 - accuracy: 0.3371 - val_loss: 0.2296 - val_accuracy: 0.3633
# Epoch 46/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2129 - accuracy: 0.3398 - val_loss: 0.2182 - val_accuracy: 0.3435
# Epoch 47/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2110 - accuracy: 0.3428 - val_loss: 0.2177 - val_accuracy: 0.3400
# Epoch 48/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2099 - accuracy: 0.3355 - val_loss: 0.2139 - val_accuracy: 0.3336
# Epoch 49/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2100 - accuracy: 0.3356 - val_loss: 0.2157 - val_accuracy: 0.3431
# Epoch 50/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2105 - accuracy: 0.3401 - val_loss: 0.2192 - val_accuracy: 0.3458
# Epoch 51/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.2113 - accuracy: 0.3371 - val_loss: 0.2173 - val_accuracy: 0.3443
# Epoch 52/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2116 - accuracy: 0.3388 - val_loss: 0.2275 - val_accuracy: 0.3563
# Epoch 53/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2088 - accuracy: 0.3349 - val_loss: 0.2209 - val_accuracy: 0.3501
# Epoch 54/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2124 - accuracy: 0.3389 - val_loss: 0.2288 - val_accuracy: 0.3670
# Epoch 55/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2107 - accuracy: 0.3369 - val_loss: 0.2191 - val_accuracy: 0.3490
# Epoch 56/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2087 - accuracy: 0.3356 - val_loss: 0.2139 - val_accuracy: 0.3336
# Epoch 57/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2086 - accuracy: 0.3318 - val_loss: 0.2118 - val_accuracy: 0.3336
# Epoch 58/100
# 70/70 [==============================] - 1s 9ms/step - loss: 0.2096 - accuracy: 0.3303 - val_loss: 0.2149 - val_accuracy: 0.3349
# Epoch 59/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2108 - accuracy: 0.3378 - val_loss: 0.2164 - val_accuracy: 0.3393
# Epoch 60/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2116 - accuracy: 0.3366 - val_loss: 0.2252 - val_accuracy: 0.3516
# Epoch 61/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2091 - accuracy: 0.3359 - val_loss: 0.2136 - val_accuracy: 0.3368
# Epoch 62/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2078 - accuracy: 0.3343 - val_loss: 0.2131 - val_accuracy: 0.3316
# Epoch 63/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.2092 - accuracy: 0.3319 - val_loss: 0.2269 - val_accuracy: 0.3571
# Epoch 64/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2109 - accuracy: 0.3361 - val_loss: 0.2196 - val_accuracy: 0.3430
# Epoch 65/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2108 - accuracy: 0.3386 - val_loss: 0.2186 - val_accuracy: 0.3418
# Epoch 66/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2087 - accuracy: 0.3293 - val_loss: 0.2171 - val_accuracy: 0.3430
# Epoch 67/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2089 - accuracy: 0.3331 - val_loss: 0.2159 - val_accuracy: 0.3390
# Epoch 68/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2091 - accuracy: 0.3306 - val_loss: 0.2191 - val_accuracy: 0.3476
# Epoch 69/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2086 - accuracy: 0.3336 - val_loss: 0.2208 - val_accuracy: 0.3508
# Epoch 70/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2097 - accuracy: 0.3345 - val_loss: 0.2152 - val_accuracy: 0.3415
# Epoch 71/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2079 - accuracy: 0.3335 - val_loss: 0.2130 - val_accuracy: 0.3353
# Epoch 72/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2083 - accuracy: 0.3333 - val_loss: 0.2200 - val_accuracy: 0.3471
# Epoch 73/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2084 - accuracy: 0.3298 - val_loss: 0.2195 - val_accuracy: 0.3465
# Epoch 74/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2078 - accuracy: 0.3291 - val_loss: 0.2132 - val_accuracy: 0.3343
# Epoch 75/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2071 - accuracy: 0.3315 - val_loss: 0.2150 - val_accuracy: 0.3353
# Epoch 76/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2077 - accuracy: 0.3270 - val_loss: 0.2129 - val_accuracy: 0.3329
# Epoch 77/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2077 - accuracy: 0.3334 - val_loss: 0.2114 - val_accuracy: 0.3346
# Epoch 78/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2063 - accuracy: 0.3261 - val_loss: 0.2148 - val_accuracy: 0.3405
# Epoch 79/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2087 - accuracy: 0.3295 - val_loss: 0.2184 - val_accuracy: 0.3461
# Epoch 80/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2096 - accuracy: 0.3338 - val_loss: 0.2151 - val_accuracy: 0.3348
# Epoch 81/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2084 - accuracy: 0.3348 - val_loss: 0.2094 - val_accuracy: 0.3269
# Epoch 82/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2068 - accuracy: 0.3270 - val_loss: 0.2107 - val_accuracy: 0.3279
# Epoch 83/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2077 - accuracy: 0.3329 - val_loss: 0.2167 - val_accuracy: 0.3400
# Epoch 84/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2082 - accuracy: 0.3325 - val_loss: 0.2166 - val_accuracy: 0.3353
# Epoch 85/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2096 - accuracy: 0.3359 - val_loss: 0.2186 - val_accuracy: 0.3406
# Epoch 86/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2086 - accuracy: 0.3324 - val_loss: 0.2141 - val_accuracy: 0.3364
# Epoch 87/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2070 - accuracy: 0.3255 - val_loss: 0.2151 - val_accuracy: 0.3361
# Epoch 88/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2081 - accuracy: 0.3298 - val_loss: 0.2142 - val_accuracy: 0.3369
# Epoch 89/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2076 - accuracy: 0.3273 - val_loss: 0.2183 - val_accuracy: 0.3398
# Epoch 90/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2087 - accuracy: 0.3338 - val_loss: 0.2102 - val_accuracy: 0.3309
# Epoch 91/100
# 70/70 [==============================] - 0s 7ms/step - loss: 0.2057 - accuracy: 0.3276 - val_loss: 0.2144 - val_accuracy: 0.3343
# Epoch 92/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2081 - accuracy: 0.3292 - val_loss: 0.2160 - val_accuracy: 0.3333
# Epoch 93/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2069 - accuracy: 0.3335 - val_loss: 0.2162 - val_accuracy: 0.3380
# Epoch 94/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2081 - accuracy: 0.3348 - val_loss: 0.2159 - val_accuracy: 0.3403
# Epoch 95/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2084 - accuracy: 0.3320 - val_loss: 0.2111 - val_accuracy: 0.3298
# Epoch 96/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2073 - accuracy: 0.3316 - val_loss: 0.2135 - val_accuracy: 0.3373
# Epoch 97/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2082 - accuracy: 0.3269 - val_loss: 0.2170 - val_accuracy: 0.3423
# Epoch 98/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2079 - accuracy: 0.3322 - val_loss: 0.2175 - val_accuracy: 0.3413
# Epoch 99/100
# 70/70 [==============================] - 1s 7ms/step - loss: 0.2079 - accuracy: 0.3275 - val_loss: 0.2152 - val_accuracy: 0.3299
# Epoch 100/100
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2085 - accuracy: 0.3293 - val_loss: 0.2139 - val_accuracy: 0.3293

# %%
def compute_accuracy(y_true, y_pred):
    '''Compute classification accuracy with a fixed threshold on distances.
    '''
    pred = y_pred.ravel() < 0.5
    return np.mean(pred == y_true)

# %% [markdown]
# ## Compute accuracy

# %%
loss = model.evaluate(x=[ts_pairs[:,0],ts_pairs[:,1]], y=ts_y)

y_pred_train = model.predict([tr_pairs[:,0], tr_pairs[:,1]])
train_accuracy = compute_accuracy(tr_y, y_pred_train)

y_pred_test = model.predict([ts_pairs[:,0], ts_pairs[:,1]])
test_accuracy = compute_accuracy(ts_y, y_pred_test)

print("Loss = {}, Train Accuracy = {} Test Accuracy = {}".format(loss, train_accuracy, test_accuracy))
# Out:
# 188/188 [==============================] - 1s 3ms/step - loss: 0.2139 - accuracy: 0.3293
# 437/437 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# Loss = [0.21389882266521454, 0.3292723596096039], Train Accuracy = 0.5 Test Accuracy = 0.5

# %% [markdown]
# ## Plot results

# %%
import matplotlib.pyplot as plt

def plot_metrics(metric_name, title):
    fig, ax = plt.subplots(figsize=((10, 10)))
    ax.set_title(title)
    ax.plot(history.history['loss'], label="Loss")
    ax.plot(history.history['val_loss'], label="Validation Loss")
    ax.plot(history.history['accuracy'], label="Accuracy")
    ax.plot(history.history['val_accuracy'], label="Validation Accuracy")
    # ax.plot(history.history['val_' + metric_name],color='green',label='val_' + metric_name)
    ax.grid()
    ax.legend(prop={'size': 15})

plot_metrics(metric_name='loss', title="Loss")

# %% [markdown]
# ## Display the most and the least similar song from training

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

min_dif = np.min(y_pred_train)
min_ind = np.where(y_pred_train == min_dif)[0][0]
max_dif = np.max(y_pred_train)
max_ind = np.where(y_pred_train == max_dif)[0][0]

fig, ax = plt.subplots(2, 2, sharex=True, figsize=(20, 10))
fig.suptitle("Training result", fontsize=20)
img0 = librosa.display.specshow(tr_pairs[min_ind,0], x_axis="time", ax=ax[0,0])
fig.colorbar(img0, ax=[ax[0,0]])
ax[0,0].set_title(f"Difference between songs is {min_dif:.4f}\n\nSong is {tr_names[min_ind][0]}")

img1 = librosa.display.specshow(tr_pairs[min_ind,1], x_axis='time', ax=ax[1,0])
fig.colorbar(img1, ax=[ax[1,0]])
ax[1,0].set_title(f"Song is {tr_names[min_ind][1]}")

img2 = librosa.display.specshow(tr_pairs[max_ind,0], x_axis='time', ax=ax[0,1])
fig.colorbar(img2, ax=[ax[0,1]])
ax[0,1].set_title(f"Difference between songs is {max_dif:.4f}\n\nSong is {tr_names[max_ind][0]}")

img3 = librosa.display.specshow(tr_pairs[max_ind,1], x_axis='time', ax=ax[1,1])
fig.colorbar(img3, ax=[ax[1,1]])
ax[1,1].set_title(f"Song is {tr_names[max_ind][1]}")
# Out:
# Text(0.5, 1.0, 'Song is pop.00049.wav')

# %% [markdown]
# ## Display the most and the least similar song from test

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

min_dif = np.min(y_pred_test)
min_ind = np.where(y_pred_test == min_dif)[0][0]
max_dif = np.max(y_pred_test)
max_ind = np.where(y_pred_test == max_dif)[0][0]

fig, ax = plt.subplots(2, 2, sharex=True, figsize=(20, 10))
fig.suptitle("Test result", fontsize=20)
img0 = librosa.display.specshow(ts_pairs[min_ind,0], x_axis="time", ax=ax[0,0])
fig.colorbar(img0, ax=[ax[0,0]])
ax[0,0].set_title(f"Difference between songs is {min_dif:.4f}\n\nSong is {ts_names[min_ind][0]}")

img1 = librosa.display.specshow(ts_pairs[min_ind,1], x_axis='time', ax=ax[1,0])
fig.colorbar(img1, ax=[ax[1,0]])
ax[1,0].set_title(f"Song is {ts_names[min_ind][1]}")

img2 = librosa.display.specshow(ts_pairs[max_ind,0], x_axis='time', ax=ax[0,1])
fig.colorbar(img2, ax=[ax[0,1]])
ax[0,1].set_title(f"Difference between songs is {max_dif:.4f}\n\nSong is {ts_names[max_ind][0]}")

img3 = librosa.display.specshow(ts_pairs[max_ind,1], x_axis='time', ax=ax[1,1])
fig.colorbar(img3, ax=[ax[1,1]])
ax[1,1].set_title(f"Song is {ts_names[max_ind][1]}")
# Out:
# Text(0.5, 1.0, 'Song is pop.00060.wav')
